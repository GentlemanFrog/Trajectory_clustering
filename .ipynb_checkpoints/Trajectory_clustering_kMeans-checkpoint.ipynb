# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv('export_tracks_star.csv', encoding='unicode_escape', decimal=',')

# %%
raw_data.shape # 69 instances 28 attribiutes in data_set
# Out:
# (69, 28)

# %% [markdown]
# # Podstawowy zestaw danych
#
# Wczytany został podstawowy plik wyjściowy z pluginu TrackMate programu Fiji służącego do śledzenia ruchu obiektów na obrazach. Jak widać na wcześniejszym wywołaniu komendy shape zestaw danych składa się z 69 instacji, z których każda posiada inforamcje takiej jak: track_id, start_frame, stop_frame oraz inne cechy ruchu, które plugin przeliczył w trakcie wykonywania procesu śledzenia. Z wczytanych danych należy wybrać użyteczne w procesie clusteringu cechy oraz dokonać ich standaryzacji.

# %%
raw_data.head()
# Out:
#        LABEL  TRACK_INDEX  TRACK_ID              NUMBER_SPOTS     NUMBER_GAPS  \
# 0      Label  Track index  Track ID  Number of spots in track  Number of gaps
# 1      Label        Index        ID                   N spots          N gaps
# 2        NaN          NaN       NaN                       NaN             NaN
# 3  Track_462            0         0                       250               0
# 4  Track_463            1         1                       388               0
#
#             NUMBER_SPLITS           NUMBER_MERGES            NUMBER_COMPLEX  \
# 0  Number of split events  Number of merge events  Number of complex points
# 1                N splits                N merges                 N complex
# 2                     NaN                     NaN                       NaN
# 3                       0                       0                         0
# 4                       0                       0                         0
#
#    LONGEST_GAP  TRACK_DURATION  ...       TRACK_MIN_SPEED  \
# 0  Longest gap  Track duration  ...       Track min speed
# 1     Lgst gap        Duration  ...             Min speed
# 2          NaN         (frame)  ...            (µm/frame)
# 3            0           249.0  ...  0.012592547401922012
# 4            0           387.0  ...  0.006485379838481075
#
#     TRACK_MEDIAN_SPEED      TRACK_STD_SPEED  TRACK_MEAN_QUALITY  \
# 0   Track median speed      Track std speed  Track mean quality
# 1           Med. speed            Std speed              Mean Q
# 2           (µm/frame)           (µm/frame)           (quality)
# 3  0.23388675075706977  0.18174506893925985  0.8538669741153717
# 4   0.2311804504869517   0.2228176755299001  0.8631979981341313
#
#    TOTAL_DISTANCE_TRAVELED  MAX_DISTANCE_TRAVELED     CONFINEMENT_RATIO  \
# 0  Total distance traveled  Max distance traveled     Confinement ratio
# 1              Total dist.              Max dist.            Cfn. ratio
# 2                     (µm)                   (µm)                   NaN
# 3        64.90332676903677     4.5710834662765505  0.055788756803038894
# 4       107.60587478993135      7.357544675894323   0.05387905095754452
#
#    MEAN_STRAIGHT_LINE_SPEED  LINEARITY_OF_FORWARD_PROGRESSION  \
# 0  Mean straight line speed  Linearity of forward progression
# 1               Mn. v. line                       Fwd. progr.
# 2                (µm/frame)                               NaN
# 3      0.014541670332634364               0.05578875680303892
# 4      0.014981143181234797              0.053879050957544465
#
#    MEAN_DIRECTIONAL_CHANGE_RATE
# 0  Mean directional change rate
# 1                    Mn. ? rate
# 2                   (rad/frame)
# 3             2.045171270476615
# 4             2.020701714445263
#
# [5 rows x 28 columns]

# %%
# Summary of dataset:
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   LABEL                             68 non-null     object
#  1   TRACK_INDEX                       68 non-null     object
#  2   TRACK_ID                          68 non-null     object
#  3   NUMBER_SPOTS                      68 non-null     object
#  4   NUMBER_GAPS                       68 non-null     object
#  5   NUMBER_SPLITS                     68 non-null     object
#  6   NUMBER_MERGES                     68 non-null     object
#  7   NUMBER_COMPLEX                    68 non-null     object
#  8   LONGEST_GAP                       68 non-null     object
#  9   TRACK_DURATION                    69 non-null     object
#  10  TRACK_START                       69 non-null     object
#  11  TRACK_STOP                        69 non-null     object
#  12  TRACK_DISPLACEMENT                69 non-null     object
#  13  TRACK_X_LOCATION                  69 non-null     object
#  14  TRACK_Y_LOCATION                  69 non-null     object
#  15  TRACK_Z_LOCATION                  69 non-null     object
#  16  TRACK_MEAN_SPEED                  69 non-null     object
#  17  TRACK_MAX_SPEED                   69 non-null     object
#  18  TRACK_MIN_SPEED                   69 non-null     object
#  19  TRACK_MEDIAN_SPEED                69 non-null     object
#  20  TRACK_STD_SPEED                   69 non-null     object
#  21  TRACK_MEAN_QUALITY                69 non-null     object
#  22  TOTAL_DISTANCE_TRAVELED           69 non-null     object
#  23  MAX_DISTANCE_TRAVELED             69 non-null     object
#  24  CONFINEMENT_RATIO                 68 non-null     object
#  25  MEAN_STRAIGHT_LINE_SPEED          69 non-null     object
#  26  LINEARITY_OF_FORWARD_PROGRESSION  68 non-null     object
#  27  MEAN_DIRECTIONAL_CHANGE_RATE      69 non-null     object
# dtypes: object(28)
# memory usage: 15.2+ KB

# %%
# Checking for any missing values in data_set:
raw_data.isnull().sum()
# Out:
# LABEL                               1
# TRACK_INDEX                         1
# TRACK_ID                            1
# NUMBER_SPOTS                        1
# NUMBER_GAPS                         1
# NUMBER_SPLITS                       1
# NUMBER_MERGES                       1
# NUMBER_COMPLEX                      1
# LONGEST_GAP                         1
# TRACK_DURATION                      0
# TRACK_START                         0
# TRACK_STOP                          0
# TRACK_DISPLACEMENT                  0
# TRACK_X_LOCATION                    0
# TRACK_Y_LOCATION                    0
# TRACK_Z_LOCATION                    0
# TRACK_MEAN_SPEED                    0
# TRACK_MAX_SPEED                     0
# TRACK_MIN_SPEED                     0
# TRACK_MEDIAN_SPEED                  0
# TRACK_STD_SPEED                     0
# TRACK_MEAN_QUALITY                  0
# TOTAL_DISTANCE_TRAVELED             0
# MAX_DISTANCE_TRAVELED               0
# CONFINEMENT_RATIO                   1
# MEAN_STRAIGHT_LINE_SPEED            0
# LINEARITY_OF_FORWARD_PROGRESSION    1
# MEAN_DIRECTIONAL_CHANGE_RATE        0
# dtype: int64

# %% [markdown]
# Widać, że w zestawie danych są wartości NaN, dlatego zostanie dokonane zastąpienie ich na 0 co ułatwi dalsze obliczenia.

# %%
raw_data.fillna(0)
# Out:
#          LABEL  TRACK_INDEX  TRACK_ID              NUMBER_SPOTS  \
# 0        Label  Track index  Track ID  Number of spots in track
# 1        Label        Index        ID                   N spots
# 2            0            0         0                         0
# 3    Track_462            0         0                       250
# 4    Track_463            1         1                       388
# ..         ...          ...       ...                       ...
# 64  Track_1752         1290      1290                         7
# 65  Track_1949         1487      1487                        10
# 66  Track_1955         1493      1493                       112
# 67  Track_2382         1920      1920                         7
# 68  Track_2453         1991      1991                         7
#
#        NUMBER_GAPS           NUMBER_SPLITS           NUMBER_MERGES  \
# 0   Number of gaps  Number of split events  Number of merge events
# 1           N gaps                N splits                N merges
# 2                0                       0                       0
# 3                0                       0                       0
# 4                0                       0                       0
# ..             ...                     ...                     ...
# 64               0                       0                       0
# 65               0                       0                       0
# 66               0                       0                       0
# 67               0                       0                       0
# 68               0                       0                       0
#
#               NUMBER_COMPLEX  LONGEST_GAP  TRACK_DURATION  ...  \
# 0   Number of complex points  Longest gap  Track duration  ...
# 1                  N complex     Lgst gap        Duration  ...
# 2                          0            0         (frame)  ...
# 3                          0            0           249.0  ...
# 4                          0            0           387.0  ...
# ..                       ...          ...             ...  ...
# 64                         0            0             6.0  ...
# 65                         0            0             9.0  ...
# 66                         0            0           111.0  ...
# 67                         0            0             6.0  ...
# 68                         0            0             6.0  ...
#
#          TRACK_MIN_SPEED   TRACK_MEDIAN_SPEED      TRACK_STD_SPEED  \
# 0        Track min speed   Track median speed      Track std speed
# 1              Min speed           Med. speed            Std speed
# 2             (µm/frame)           (µm/frame)           (µm/frame)
# 3   0.012592547401922012  0.23388675075706977  0.18174506893925985
# 4   0.006485379838481075   0.2311804504869517   0.2228176755299001
# ..                   ...                  ...                  ...
# 64   0.11313719842926159   0.5056825498122379  0.31140483798019997
# 65      0.15756360738414   0.4205805291623273  0.28707468622742166
# 66  0.013433660790994598   0.3108161760602851  0.20583460463221723
# 67   0.03128939605962908   0.6689424238242826  0.47779104997852195
# 68   0.46746661473851103   0.7921493734268222  0.37496891577066105
#
#     TRACK_MEAN_QUALITY  TOTAL_DISTANCE_TRAVELED  MAX_DISTANCE_TRAVELED  \
# 0   Track mean quality  Total distance traveled  Max distance traveled
# 1               Mean Q              Total dist.              Max dist.
# 2            (quality)                     (µm)                   (µm)
# 3   0.8538669741153717        64.90332676903677     4.5710834662765505
# 4   0.8631979981341313       107.60587478993135      7.357544675894323
# ..                 ...                      ...                    ...
# 64  0.8376826473644802       3.2495811973447735     2.4337332972043533
# 65  0.8658081471920014        4.530849745677954     2.3252283797180815
# 66  0.8171434232166835        37.11425651897602      4.225057235810097
# 67  0.8170451521873474        3.484193931709708     2.2178356360452063
# 68   0.878492363861629        4.950335032713836      2.336005137896933
#
#        CONFINEMENT_RATIO  MEAN_STRAIGHT_LINE_SPEED  \
# 0      Confinement ratio  Mean straight line speed
# 1             Cfn. ratio               Mn. v. line
# 2                      0                (µm/frame)
# 3   0.055788756803038894      0.014541670332634364
# 4    0.05387905095754452      0.014981143181234797
# ..                   ...                       ...
# 64    0.7489375243778958        0.4056222162007255
# 65     0.513199181221172        0.2583587088575646
# 66     0.107259632611456       0.03586361728714148
# 67    0.6365419604978491       0.36963927267420105
# 68   0.47188829088529505       0.38933418964948885
#
#     LINEARITY_OF_FORWARD_PROGRESSION  MEAN_DIRECTIONAL_CHANGE_RATE
# 0   Linearity of forward progression  Mean directional change rate
# 1                        Fwd. progr.                    Mn. ? rate
# 2                                  0                   (rad/frame)
# 3                0.05578875680303892             2.045171270476615
# 4               0.053879050957544465             2.020701714445263
# ..                               ...                           ...
# 64                0.7489375243778957            1.4176807337398047
# 65                 0.513199181221172            1.4004037242686547
# 66               0.10725963261145606            1.9456591851395075
# 67                0.6365419604978491            1.9605242126884683
# 68               0.47188829088529505            2.3910608229149855
#
# [69 rows x 28 columns]

# %% [markdown]
# Teraz ze raw_data wybieramy kolumny, które mogą być użyteczne w clusteringu

# %%
data_to_clust = raw_data[['LABEL', 'TRACK_MIN_SPEED', 'TRACK_MEDIAN_SPEED','TRACK_STD_SPEED', 'TOTAL_DISTANCE_TRAVELED',
                          'CONFINEMENT_RATIO', 'MEAN_STRAIGHT_LINE_SPEED', 'LINEARITY_OF_FORWARD_PROGRESSION', 'MEAN_DIRECTIONAL_CHANGE_RATE']].copy()

# %%
data_to_clust.head()
# Out:
#        LABEL       TRACK_MIN_SPEED   TRACK_MEDIAN_SPEED      TRACK_STD_SPEED  \
# 0      Label       Track min speed   Track median speed      Track std speed
# 1      Label             Min speed           Med. speed            Std speed
# 2        NaN            (µm/frame)           (µm/frame)           (µm/frame)
# 3  Track_462  0.012592547401922012  0.23388675075706977  0.18174506893925985
# 4  Track_463  0.006485379838481075   0.2311804504869517   0.2228176755299001
#
#    TOTAL_DISTANCE_TRAVELED     CONFINEMENT_RATIO  MEAN_STRAIGHT_LINE_SPEED  \
# 0  Total distance traveled     Confinement ratio  Mean straight line speed
# 1              Total dist.            Cfn. ratio               Mn. v. line
# 2                     (µm)                   NaN                (µm/frame)
# 3        64.90332676903677  0.055788756803038894      0.014541670332634364
# 4       107.60587478993135   0.05387905095754452      0.014981143181234797
#
#    LINEARITY_OF_FORWARD_PROGRESSION  MEAN_DIRECTIONAL_CHANGE_RATE
# 0  Linearity of forward progression  Mean directional change rate
# 1                       Fwd. progr.                    Mn. ? rate
# 2                               NaN                   (rad/frame)
# 3               0.05578875680303892             2.045171270476615
# 4              0.053879050957544465             2.020701714445263

# %%
data_droped = data_to_clust.drop(data_to_clust.index[[0,1,2]]) # deletion of useless rows
data_droped
# Out:
#          LABEL       TRACK_MIN_SPEED   TRACK_MEDIAN_SPEED  \
# 3    Track_462  0.012592547401922012  0.23388675075706977
# 4    Track_463  0.006485379838481075   0.2311804504869517
# 5    Track_464  0.009966538653811906   0.2670637310519622
# 6    Track_466  0.006818754898762113  0.24815805076910447
# 7    Track_472   0.05305654674570058  0.29669586586900115
# ..         ...                   ...                  ...
# 64  Track_1752   0.11313719842926159   0.5056825498122379
# 65  Track_1949      0.15756360738414   0.4205805291623273
# 66  Track_1955  0.013433660790994598   0.3108161760602851
# 67  Track_2382   0.03128939605962908   0.6689424238242826
# 68  Track_2453   0.46746661473851103   0.7921493734268222
#
#         TRACK_STD_SPEED TOTAL_DISTANCE_TRAVELED     CONFINEMENT_RATIO  \
# 3   0.18174506893925985       64.90332676903677  0.055788756803038894
# 4    0.2228176755299001      107.60587478993135   0.05387905095754452
# 5     0.204719869900998       140.2107329235038  0.034549348727096744
# 6   0.16263472631130754       65.61069861340832   0.06506995068449287
# 7   0.27679530735415286      29.285207240302523   0.10076665096718647
# ..                  ...                     ...                   ...
# 64  0.31140483798019997      3.2495811973447735    0.7489375243778958
# 65  0.28707468622742166       4.530849745677954     0.513199181221172
# 66  0.20583460463221723       37.11425651897602     0.107259632611456
# 67  0.47779104997852195       3.484193931709708    0.6365419604978491
# 68  0.37496891577066105       4.950335032713836   0.47188829088529505
#
#    MEAN_STRAIGHT_LINE_SPEED LINEARITY_OF_FORWARD_PROGRESSION  \
# 3      0.014541670332634364              0.05578875680303892
# 4      0.014981143181234797             0.053879050957544465
# 5      0.010134287671665182             0.034549348727096765
# 6      0.016808208358856706              0.06506995068449282
# 7       0.03688715320606608              0.10076665096718647
# ..                      ...                              ...
# 64       0.4056222162007255               0.7489375243778957
# 65       0.2583587088575646                0.513199181221172
# 66      0.03586361728714148              0.10725963261145606
# 67      0.36963927267420105               0.6365419604978491
# 68      0.38933418964948885              0.47188829088529505
#
#    MEAN_DIRECTIONAL_CHANGE_RATE
# 3             2.045171270476615
# 4             2.020701714445263
# 5            2.0379597930381035
# 6            2.0735463328127977
# 7            2.0789072669704587
# ..                          ...
# 64           1.4176807337398047
# 65           1.4004037242686547
# 66           1.9456591851395075
# 67           1.9605242126884683
# 68           2.3910608229149855
#
# [66 rows x 9 columns]

# %%
# replacing all dots to commas in data frame
data_droped.apply(lambda x: x.str.replace('.',','))
# Out:
#          LABEL       TRACK_MIN_SPEED   TRACK_MEDIAN_SPEED  \
# 3    Track_462  0,012592547401922012  0,23388675075706977
# 4    Track_463  0,006485379838481075   0,2311804504869517
# 5    Track_464  0,009966538653811906   0,2670637310519622
# 6    Track_466  0,006818754898762113  0,24815805076910447
# 7    Track_472   0,05305654674570058  0,29669586586900115
# ..         ...                   ...                  ...
# 64  Track_1752   0,11313719842926159   0,5056825498122379
# 65  Track_1949      0,15756360738414   0,4205805291623273
# 66  Track_1955  0,013433660790994598   0,3108161760602851
# 67  Track_2382   0,03128939605962908   0,6689424238242826
# 68  Track_2453   0,46746661473851103   0,7921493734268222
#
#         TRACK_STD_SPEED TOTAL_DISTANCE_TRAVELED     CONFINEMENT_RATIO  \
# 3   0,18174506893925985       64,90332676903677  0,055788756803038894
# 4    0,2228176755299001      107,60587478993135   0,05387905095754452
# 5     0,204719869900998       140,2107329235038  0,034549348727096744
# 6   0,16263472631130754       65,61069861340832   0,06506995068449287
# 7   0,27679530735415286      29,285207240302523   0,10076665096718647
# ..                  ...                     ...                   ...
# 64  0,31140483798019997      3,2495811973447735    0,7489375243778958
# 65  0,28707468622742166       4,530849745677954     0,513199181221172
# 66  0,20583460463221723       37,11425651897602     0,107259632611456
# 67  0,47779104997852195       3,484193931709708    0,6365419604978491
# 68  0,37496891577066105       4,950335032713836   0,47188829088529505
#
#    MEAN_STRAIGHT_LINE_SPEED LINEARITY_OF_FORWARD_PROGRESSION  \
# 3      0,014541670332634364              0,05578875680303892
# 4      0,014981143181234797             0,053879050957544465
# 5      0,010134287671665182             0,034549348727096765
# 6      0,016808208358856706              0,06506995068449282
# 7       0,03688715320606608              0,10076665096718647
# ..                      ...                              ...
# 64       0,4056222162007255               0,7489375243778957
# 65       0,2583587088575646                0,513199181221172
# 66      0,03586361728714148              0,10725963261145606
# 67      0,36963927267420105               0,6365419604978491
# 68      0,38933418964948885              0,47188829088529505
#
#    MEAN_DIRECTIONAL_CHANGE_RATE
# 3             2,045171270476615
# 4             2,020701714445263
# 5            2,0379597930381035
# 6            2,0735463328127977
# 7            2,0789072669704587
# ..                          ...
# 64           1,4176807337398047
# 65           1,4004037242686547
# 66           1,9456591851395075
# 67           1,9605242126884683
# 68           2,3910608229149855
#
# [66 rows x 9 columns]

# %%
# it will let us save the proper index order after scaling step
data_droped = data_droped.reset_index(level=None, drop=True)
data_droped
# Out:
#          LABEL       TRACK_MIN_SPEED   TRACK_MEDIAN_SPEED  \
# 0    Track_462  0.012592547401922012  0.23388675075706977
# 1    Track_463  0.006485379838481075   0.2311804504869517
# 2    Track_464  0.009966538653811906   0.2670637310519622
# 3    Track_466  0.006818754898762113  0.24815805076910447
# 4    Track_472   0.05305654674570058  0.29669586586900115
# ..         ...                   ...                  ...
# 61  Track_1752   0.11313719842926159   0.5056825498122379
# 62  Track_1949      0.15756360738414   0.4205805291623273
# 63  Track_1955  0.013433660790994598   0.3108161760602851
# 64  Track_2382   0.03128939605962908   0.6689424238242826
# 65  Track_2453   0.46746661473851103   0.7921493734268222
#
#         TRACK_STD_SPEED TOTAL_DISTANCE_TRAVELED     CONFINEMENT_RATIO  \
# 0   0.18174506893925985       64.90332676903677  0.055788756803038894
# 1    0.2228176755299001      107.60587478993135   0.05387905095754452
# 2     0.204719869900998       140.2107329235038  0.034549348727096744
# 3   0.16263472631130754       65.61069861340832   0.06506995068449287
# 4   0.27679530735415286      29.285207240302523   0.10076665096718647
# ..                  ...                     ...                   ...
# 61  0.31140483798019997      3.2495811973447735    0.7489375243778958
# 62  0.28707468622742166       4.530849745677954     0.513199181221172
# 63  0.20583460463221723       37.11425651897602     0.107259632611456
# 64  0.47779104997852195       3.484193931709708    0.6365419604978491
# 65  0.37496891577066105       4.950335032713836   0.47188829088529505
#
#    MEAN_STRAIGHT_LINE_SPEED LINEARITY_OF_FORWARD_PROGRESSION  \
# 0      0.014541670332634364              0.05578875680303892
# 1      0.014981143181234797             0.053879050957544465
# 2      0.010134287671665182             0.034549348727096765
# 3      0.016808208358856706              0.06506995068449282
# 4       0.03688715320606608              0.10076665096718647
# ..                      ...                              ...
# 61       0.4056222162007255               0.7489375243778957
# 62       0.2583587088575646                0.513199181221172
# 63      0.03586361728714148              0.10725963261145606
# 64      0.36963927267420105               0.6365419604978491
# 65      0.38933418964948885              0.47188829088529505
#
#    MEAN_DIRECTIONAL_CHANGE_RATE
# 0             2.045171270476615
# 1             2.020701714445263
# 2            2.0379597930381035
# 3            2.0735463328127977
# 4            2.0789072669704587
# ..                          ...
# 61           1.4176807337398047
# 62           1.4004037242686547
# 63           1.9456591851395075
# 64           1.9605242126884683
# 65           2.3910608229149855
#
# [66 rows x 9 columns]

# %%
data_droped_no_label = data_droped.drop('LABEL',1)

# %%
# converting the string type of data to float type
data_droped_float = data_droped_no_label.astype(float)
data_droped_float.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   TRACK_MIN_SPEED                   66 non-null     float64
#  1   TRACK_MEDIAN_SPEED                66 non-null     float64
#  2   TRACK_STD_SPEED                   66 non-null     float64
#  3   TOTAL_DISTANCE_TRAVELED           66 non-null     float64
#  4   CONFINEMENT_RATIO                 66 non-null     float64
#  5   MEAN_STRAIGHT_LINE_SPEED          66 non-null     float64
#  6   LINEARITY_OF_FORWARD_PROGRESSION  66 non-null     float64
#  7   MEAN_DIRECTIONAL_CHANGE_RATE      66 non-null     float64
# dtypes: float64(8)
# memory usage: 4.2 KB

# %% [markdown]
# # Skalowanie cech

# %%
from sklearn.preprocessing import MinMaxScaler
# W celu zachowania informacji, która kolumna jest która
cols = data_droped_float.columns
ms = MinMaxScaler()
# Fit_transform scaler fit on the whole dataset and then used to create a
# transformed version of the dataset with each column standardize independently.
data_scaled = ms.fit_transform(data_droped_float)
# Dodatkowo MinMaxScaler pozwala na dostosowanie cech, których rozkład
# przypomina rozkład noramlny

# %%
data_scaled = pd.DataFrame(data_scaled, columns=[cols])

# %%
data_scaled.head()
# Out:
#   TRACK_MIN_SPEED TRACK_MEDIAN_SPEED TRACK_STD_SPEED TOTAL_DISTANCE_TRAVELED  \
# 0        0.012173           0.056391        0.164951                0.453668
# 1        0.005256           0.054349        0.280803                0.763462
# 2        0.009199           0.081429        0.229755                1.000000
# 3        0.005633           0.067161        0.111047                0.458800
# 4        0.058005           0.103792        0.433057                0.195269
#
#   CONFINEMENT_RATIO MEAN_STRAIGHT_LINE_SPEED LINEARITY_OF_FORWARD_PROGRESSION  \
# 0          0.031402                 0.006764                         0.031402
# 1          0.029358                 0.007153                         0.029358
# 2          0.008661                 0.002866                         0.008661
# 3          0.041340                 0.008769                         0.041340
# 4          0.079562                 0.026527                         0.079562
#
#   MEAN_DIRECTIONAL_CHANGE_RATE
# 0                     0.829013
# 1                     0.816917
# 2                     0.825449
# 3                     0.843040
# 4                     0.845690

# %%
# adding label to existing scaled data set
#track_labels = data_droped['LABEL']
#data_scaled = data_scaled.join(track_labels)
#data_scaled

# %% [markdown]
# # K-means

# %%
# Making elbow plot to consider number of K in our dataset
from sklearn.cluster import KMeans
# PAMIETAĆ o konwersji df na np.array!!!!!
X = np.array(data_scaled.loc[:,['TRACK_MIN_SPEED', 'TRACK_MEDIAN_SPEED', 'TRACK_STD_SPEED', 'TOTAL_DISTANCE_TRAVELED',
                                'CONFINEMENT_RATIO', 'MEAN_STRAIGHT_LINE_SPEED', 'LINEARITY_OF_FORWARD_PROGRESSION',
                                'MEAN_DIRECTIONAL_CHANGE_RATE']]).reshape(-1,2)
# after reshaping array we got array with 264 rows in 2 columns
X2 = np.array(data_scaled.loc[:,['TRACK_MIN_SPEED', 'TRACK_MEDIAN_SPEED', 'TRACK_STD_SPEED', 'TOTAL_DISTANCE_TRAVELED',
                                'CONFINEMENT_RATIO', 'MEAN_STRAIGHT_LINE_SPEED', 'LINEARITY_OF_FORWARD_PROGRESSION',
                                'MEAN_DIRECTIONAL_CHANGE_RATE']])
disortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X)
    disortions.append(kmeanModel.inertia_)

# %% [markdown]
# ## Ploting the disortions of K-means

# %%
plt.figure(figsize=(10,10))
plt.plot(K, disortions, 'bx-')
plt.xlabel('K')
plt.ylabel("Disortion")
plt.title("The Elbow method for finding the optimal cluster number")
plt.show()

# %% [markdown]
# ## The Silhouette method

# %%
from sklearn.metrics import silhouette_score

sil = []
kmax = range(2,11)

# we have to start from 2 clusters in silhouette coefficient
for k in kmax:
    kmeans = KMeans(n_clusters=k).fit(X)
    labels = kmeans.labels_
    sil.append(silhouette_score(X, labels, metric = 'euclidean'))

# %%
plt.figure(figsize=(12,8))
plt.plot(kmax, sil)
plt.xlabel('K')
plt.ylabel("Silhouette Score")
plt.title("The Silhouette method for finding the optimal cluster number")
plt.show()

# %% [markdown]
# W oparciu o powyższe ploty wydawało by się, że odpowiednią liczbą klastrów dla tego zbioru danych jest 3.

# %% [markdown]
# ## K-means clustering

# %% [markdown]
# Wywołanie:
# - init: kmeans++ - zamiast random aby upewnić się, że centroidy są inicjowane z pewną odległoscia między sobą
# - n_init: 50 -zwiększamy liczbe inicjalizacji, w celu znalezienia stabilnego rozwiązania
# - max_iter: 100 - Zwiększamy liczbe iteracji aby zapewnić zbieżność wyników algorytmu
# - random: 0 - ustawiamy seed żeby nasze obliczenia mogły być powtórzone przy ponownym uruchomieniu.

# %%
import hvplot.pandas

# %%
# raw data visualization:
data_droped_float.hvplot(
    kind='scatter',
    x='TOTAL_DISTANCE_TRAVELED',
    y=['TRACK_MIN_SPEED', 'TRACK_MEDIAN_SPEED', 'TRACK_STD_SPEED',
      'CONFINEMENT_RATIO', 'MEAN_STRAIGHT_LINE_SPEED', 'LINEARITY_OF_FORWARD_PROGRESSION',
      'MEAN_DIRECTIONAL_CHANGE_RATE'],
    backend='plotly',
    width=1000,
)
# Out:
# WARNING:param.main: backend option not found for scatter plot; similar options include: []
# :NdOverlay   [Variable]
#    :Scatter   [TOTAL_DISTANCE_TRAVELED]   (value)

# %%
# Kmeans
kmeans2 = KMeans(n_clusters=3, init='k-means++',n_init=50,max_iter=100, 
                random_state=0)
labels = kmeans2.fit_predict(X)
#labels

# %%
plt.scatter(X[:,0], X[:,1])
# Plot clusters:
plt.scatter(kmeans2.cluster_centers_[:, 0],
           kmeans2.cluster_centers_[:,1],
           s=200, # centroid size
           c='red', #centroid color
           )
plt.show()

# %%
# ploting with diffrent cluster colors:
u_labels = np.unique(labels)
# ploting:
for i in u_labels:
    plt.scatter(X[labels==i,0], X[labels==i, 1], label=i)
plt.legend()
plt.show()

# %% [markdown]
# ## Analiza klastrowania
#
# Algorytm wyznaczył dwa konkretne klastry w danych plus jeden dodatkowy na rozsianych punktach, które trudno zaklasyfikować. Uważam, że taka sytuacja może wynikać z większej ilości cech.

# %% [markdown]
# ## Porównanie cechy każda z każdą / polar plot

# %%
import plotly.express as px

# %% [markdown]
# ## Korelacja rangowa Spearman'a

# %%
from pylab import rcParams
import scipy
from scipy.stats import spearmanr
from scipy.stats import chi2_contingency
import itertools

sns.pairplot(data_scaled)

# %% [markdown]
# Widać na podstawie histogramów, że rozkład tych cech nie jest podobny do rozkładu normalnego (na podstawie histogramów)

# %%
# Separetion of each column
min_speed = data_scaled[['TRACK_MIN_SPEED']]
#print(min_speed)
med_speed = data_scaled[['TRACK_MEDIAN_SPEED']]
std_speed = data_scaled[['TRACK_STD_SPEED']]
total_traveled = data_scaled[['TOTAL_DISTANCE_TRAVELED']]
con_ratio = data_scaled[['CONFINEMENT_RATIO']]
str_line_speed = data_scaled[['MEAN_STRAIGHT_LINE_SPEED']]
lin_off_progg = data_scaled[['LINEARITY_OF_FORWARD_PROGRESSION']]
mean_dir_chg = data_scaled[['MEAN_DIRECTIONAL_CHANGE_RATE']]

feature_list=[min_speed, med_speed, std_speed, total_traveled, con_ratio,
             str_line_speed, lin_off_progg, mean_dir_chg]
# Creating out put for spearman:
#spearmanr_coefficient, p_value = spearmanr(min_speed, med_speed)
print("Spearman Rank Correletion Coefficient:")

for a,b in itertools.combinations(feature_list, 2):
    spearmanr_coefficient, p_value = spearmanr(a, b)
    print(f"Between {a.columns} and {b.columns}:{spearmanr_coefficient} \n")
# Out:
# Spearman Rank Correletion Coefficient:
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ):0.6282225237449118
#
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('TRACK_STD_SPEED',)],
#            ):0.5758271579167102
#
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ):-0.5372090595971194
#
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('CONFINEMENT_RATIO',)],
#            ):0.3563928608704729
#
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ):0.51829662874439
#
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ):0.3563928608704729
#
# Between MultiIndex([('TRACK_MIN_SPEED',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):-0.06736248825801067
#
# Between MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ) and MultiIndex([('TRACK_STD_SPEED',)],
#            ):0.7421146018160943
#
# Between MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ) and MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ):-0.29940507253940096
#
# Between MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ) and MultiIndex([('CONFINEMENT_RATIO',)],
#            ):0.19853877465817768
#
# Between MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ) and MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ):0.46201857843648897
#
# Between MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ) and MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ):0.19853877465817768
#
# Between MultiIndex([('TRACK_MEDIAN_SPEED',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):-0.008287235152906797
#
# Between MultiIndex([('TRACK_STD_SPEED',)],
#            ) and MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ):-0.2860452979855965
#
# Between MultiIndex([('TRACK_STD_SPEED',)],
#            ) and MultiIndex([('CONFINEMENT_RATIO',)],
#            ):0.24037156872977772
#
# Between MultiIndex([('TRACK_STD_SPEED',)],
#            ) and MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ):0.46535852207494005
#
# Between MultiIndex([('TRACK_STD_SPEED',)],
#            ) and MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ):0.24037156872977772
#
# Between MultiIndex([('TRACK_STD_SPEED',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):0.024527711094875275
#
# Between MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ) and MultiIndex([('CONFINEMENT_RATIO',)],
#            ):-0.6721010332950632
#
# Between MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ) and MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ):-0.6814528754827264
#
# Between MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ) and MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ):-0.6721010332950632
#
# Between MultiIndex([('TOTAL_DISTANCE_TRAVELED',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):0.21127230977977252
#
# Between MultiIndex([('CONFINEMENT_RATIO',)],
#            ) and MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ):0.9314059075253106
#
# Between MultiIndex([('CONFINEMENT_RATIO',)],
#            ) and MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ):1.0
#
# Between MultiIndex([('CONFINEMENT_RATIO',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):-0.2420415405490033
#
# Between MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ) and MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ):0.9314059075253106
#
# Between MultiIndex([('MEAN_STRAIGHT_LINE_SPEED',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):-0.1375013046654838
#
# Between MultiIndex([('LINEARITY_OF_FORWARD_PROGRESSION',)],
#            ) and MultiIndex([('MEAN_DIRECTIONAL_CHANGE_RATE',)],
#            ):-0.2420415405490033

# %% [markdown]
# ## Chi-square test

# %%
print("Chi-square statistics: (same order of features as above)")
#for a,b in itertools.combinations(feature_list, 2):
#    # creating cross-table with all varaibles:
#    cross_tab = pd.crosstab(a, b)
#    chi2, p, dof, expected = chi2_contingency(cross_tab.values)
#    print(f'Chisqr: {chi2} p_value: {p}\n')
# Out:
# Chi-square statistics: (same order of features as above)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1670         blocks = form_blocks(arrays, names, axes)
# -> 1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#
# ValueError: Shape of passed values is (1, 2), indices imply (66, 2)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-de2fa4250bea> in <module>
#       1 print("Chi-square statistics: (same order of features as above)")
# ----> 2 cross_tab = pd.crosstab(min_speed, std_speed)
#       3 #for a,b in itertools.combinations(feature_list, 2):
#       4 #    # creating cross-table with all varaibles:
#       5 #    cross_tab = pd.crosstab(a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     579     from pandas import DataFrame
#     580
# --> 581     df = DataFrame(data, index=common_idx)
#     582     if values is None:
#     583         df["__dummy__"] = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      72     axes = [ensure_index(columns), index]
#      73
# ---> 74     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      75
#      76
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1673         return mgr
#    1674     except ValueError as e:
# -> 1675         construction_error(len(arrays), arrays[0].shape, axes, e)
#    1676
#    1677
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (1, 2), indices imply (66, 2)

# %% [markdown]
# ## Inne metody do zastosowania:
#
# 1. Zrobić rzutowania każdej cechy z każdą i sprawdzić jej pokrycie z wynikiem klastrowania
# 2. Korelacja rangowa spearmana lub pearsona
# 3. KOlejne podejście do polar plota

# %%
for i in range(len(feature_list)):
    for j in range(i+1, len(feature_list)):
        corss_tab = pd.crosstab[i][j]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-c5f5490a7778> in <module>
#       1 for i in range(len(feature_list)):
#       2     for j in range(i+1, len(feature_list)):
# ----> 3         corss_tab = pd.crosstab[i][j]
#
# TypeError: 'function' object is not subscriptable
